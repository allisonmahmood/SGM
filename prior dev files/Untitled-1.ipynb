# %% [markdown]
# # Import Required Libraries
# Import the necessary libraries, including Scikit RF and visualization libraries like Matplotlib and NumPy.

# %%
# Import the necessary libraries
import skrf as rf
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Set up the 3D space dimensions
space_dim = 500  # 500m x 500m x 500m

# %% [markdown]
# # Define Simulation Space
# Define the 500m x 500m x 500m space using appropriate data structures.

# %%
# Define the 3D space using a grid
x = np.linspace(0, space_dim, 100)  # 100 points along x-axis
y = np.linspace(0, space_dim, 100)  # 100 points along y-axis
z = np.linspace(0, space_dim, 100)  # 100 points along z-axis
X, Y, Z = np.meshgrid(x, y, z)

# Visualize the 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X axis (m)')
ax.set_ylabel('Y axis (m)')
ax.set_zlabel('Z axis (m)')
ax.set_xlim([0, space_dim])
ax.set_ylim([0, space_dim])
ax.set_zlim([0, space_dim])
plt.show()

# %% [markdown]
# # Initialize Scikit RF
# Initialize Scikit RF for RF computations.

# %%
# Initialize Scikit RF for RF computations
# Create a Network object for the emitter at 2.4 GHz
frequency = rf.Frequency(2.4, 2.4, 1, 'ghz')
emitter = rf.Network(frequency=frequency)

# Print the emitter details
print(emitter)
# Out:
# 0-Port Network: '',  2.4-2.4 GHz, 1 pts, z0=(50+0j)

# %% [markdown]
# # Add RF Emitter
# Add an RF emitter at 2.4 GHz in the defined space.

# %%
# Add RF Emitter

# Define the emitter position in the 3D space
emitter_position = np.array([250, 250, 250])  # Center of the space

# Visualize the emitter in the 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(emitter_position[0], emitter_position[1], emitter_position[2], color='r', s=100, label='Emitter (2.4 GHz)')
ax.set_xlabel('X axis (m)')
ax.set_ylabel('Y axis (m)')
ax.set_zlabel('Z axis (m)')
ax.set_xlim([0, space_dim])
ax.set_ylim([0, space_dim])
ax.set_zlim([0, space_dim])
ax.legend()
plt.show()

# %% [markdown]
# # Visualize 3D Space
# Use a 3D visualization library to visualize the space and the effect of the emitter.

# %%
# Visualize 3D Space
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Visualize the 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X axis (m)')
ax.set_ylabel('Y axis (m)')
ax.set_zlabel('Z axis (m)')
ax.set_xlim([0, space_dim])
ax.set_ylim([0, space_dim])
ax.set_zlim([0, space_dim])
plt.show()

# Visualize the emitter in the 3D space
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(emitter_position[0], emitter_position[1], emitter_position[2], color='r', s=100, label='Emitter (2.4 GHz)')
ax.set_xlabel('X axis (m)')
ax.set_ylabel('Y axis (m)')
ax.set_zlabel('Z axis (m)')
ax.set_xlim([0, space_dim])
ax.set_ylim([0, space_dim])
ax.set_zlim([0, space_dim])
ax.legend()
plt.show()

# %% [markdown]
# # Future Enhancements: Adding Antennas
# Outline the steps to add antennas in the future to pick up signals and measure their amplitude.

# %%
# Future Enhancements: Adding Antennas

# Define a function to add antennas in the 3D space
def add_antenna(position, label):
    """
    Adds an antenna at the specified position in the 3D space.
    
    Parameters:
    position (array-like): The (x, y, z) coordinates of the antenna.
    label (str): The label for the antenna.
    """
    ax.scatter(position[0], position[1], position[2], color='b', s=100, label=label)
    ax.legend()

# Example usage: Add an antenna at a specific position
antenna_position = np.array([100, 100, 100])  # Example position
add_antenna(antenna_position, 'Antenna 1')

# Visualize the 3D space with the emitter and the antenna
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(emitter_position[0], emitter_position[1], emitter_position[2], color='r', s=100, label='Emitter (2.4 GHz)')
add_antenna(antenna_position, 'Antenna 1')
ax.set_xlabel('X axis (m)')
ax.set_ylabel('Y axis (m)')
ax.set_zlabel('Z axis (m)')
ax.set_xlim([0, space_dim])
ax.set_ylim([0, space_dim])
ax.set_zlim([0, space_dim])
ax.legend()
plt.show()
